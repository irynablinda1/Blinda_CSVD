# %% [markdown]
# # Лабораторна робота №1.2
# ### Блінда Ірина Ігорівна ФІТ 4-4
# ### Тема: Візуалізація даних з використанням бібліотеки Seaborn

# %% [markdown]
# ## Завдання 1

# %% [markdown]
# Зчитати архів  Customer Shopping Trends Dataset  за посиланням https://www.kaggle.com/datasets/iamsouravbanerjee/customer-shopping-trends-dataset

# %%
import pandas as pd

# Завантаження даних
df = pd.read_csv("E:/University/completed_tasks/KSVD_completed/shopping_trends.csv")

df.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
# 5        Wyoming    M      White  Summer            2.9                 Yes
# 6        Montana    M       Gray    Fall            3.2                 Yes
# 7      Louisiana    L   Charcoal  Winter            3.2                 Yes
# 8  West Virginia    L     Silver  Summer            2.6                 Yes
# 9       Missouri    M       Pink  Spring            4.8                 Yes
#
#   Payment Method   Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card         Express              Yes             Yes
# 1  Bank Transfer         Express              Yes             Yes
# 2           Cash   Free Shipping              Yes             Yes
# 3         PayPal    Next Day Air              Yes             Yes
# 4           Cash   Free Shipping              Yes             Yes
# 5          Venmo        Standard              Yes             Yes
# 6     Debit Card   Free Shipping              Yes             Yes
# 7     Debit Card   Free Shipping              Yes             Yes
# 8          Venmo         Express              Yes             Yes
# 9         PayPal  2-Day Shipping              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly
# 2                  23              Credit Card                 Weekly
# 3                  49                   PayPal                 Weekly
# 4                  31                   PayPal               Annually
# 5                  14                    Venmo                 Weekly
# 6                  49                     Cash              Quarterly
# 7                  19              Credit Card                 Weekly
# 8                   8                    Venmo               Annually
# 9                   4                     Cash              Quarterly

# %% [markdown]
# Далі працюємо з файлом shopping_trends.csv
#
# Загрузіть цей файл. Перевірте розмір таблиці, наявність пропусків, дублікатів, тип стовпців. Перейменуйте назви стовпців: Змініть прописні букви на строчні (маленькі) та пробіл на підкреслення.

# %%
# Перевірка розміру таблиці
print("Розмір таблиці:", df.shape)

# Перевірка наявності пропусків
print("Пропуски:")
print(df.isnull().sum())

# Перевірка наявності дублікатів
print("Дублікати:", df.duplicated().sum())

# Перевірка типів стовпців
print("Типи стовпців:")
print(df.dtypes)

# Перейменування назв стовпців
df.columns = df.columns.str.lower().str.replace(' ', '_')

# Перевірка результатів перейменування
print("\nНові назви стовпців:")
print(df.columns)
# Out:
# Розмір таблиці: (3900, 19)
# Пропуски:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64
# Дублікати: 0
# Типи стовпців:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object
#
# Нові назви стовпців:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'payment_method',
#        'shipping_type', 'discount_applied', 'promo_code_used',
#        'previous_purchases', 'preferred_payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %% [markdown]
# Далі виконайте наступні завдання. Побудуйте графіки з використанням бібліотеки seaborn.
#
# 1.	Гістограма віку (age):
# Побудуйте гістограму віку клієнтів, використовуючи Seaborn.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Налаштування стилю графіків
sns.set_style("whitegrid")

# Гістограма віку (age)
# Побудуйте гістограму віку клієнтів, використовуючи Seaborn. 
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=30, kde=True, color='#F25278')
plt.title('Гістограма віку')
plt.xlabel('Вік')
plt.ylabel('Кількість клієнтів')
plt.show()

# %% [markdown]
# 2.	Порівняння розподілу покупок за статтею (item_purchased):
# Створіть стовпчасту діаграму або графік розподілу, щоб порівняти, які товари покупають клієнти найчастіше.

# %%
# Порівняння розподілу покупок за статтю (item_purchased)
# Створіть стовпчасту діаграму або графік розподілу, щоб порівняти, які товари покупають клієнти найчастіше. 
plt.figure(figsize=(8, 6))
sns.countplot(data=df, y='item_purchased', order=df['item_purchased'].value_counts().index, hue="gender", palette='pastel')
plt.title('Розподіл покупок')
plt.xlabel('Кількість покупок')
plt.ylabel('Товар')
plt.show()

# %% [markdown]
# 3.	Залежність між віком та сумою покупок (purchase_amount):
# Використовуйте scatter plot, щоб візуалізувати залежність між віком та сумою покупок.

# %%
# Залежність між віком та сумою покупок (purchase_amount): 
# Використовуйте scatter plot, щоб візуалізувати залежність між віком та сумою покупок. 

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='age', y='purchase_amount_(usd)', color='#B2EC5D')
plt.title('Залежність між віком та сумою покупок')
plt.xlabel('Вік')
plt.ylabel('Сума покупок')
plt.show()

# %% [markdown]
# 4.	Графік розподілу оцінок товарів (review_rating):
# Побудуйте графік розподілу оцінок товарів для оцінки якості.

# %%
# Графік розподілу оцінок товарів (review_rating): 
# Побудуйте графік розподілу оцінок товарів для оцінки якості. 

plt.figure(figsize=(10, 6))
sns.histplot(df['review_rating'], bins=5, kde=True, color='salmon')
plt.title('Графік розподілу оцінок товарів')
plt.xlabel('Оцінка')
plt.ylabel('Кількість товарів')
plt.show()

# %% [markdown]
# 5.	Категоріальна діаграма для статі (gender):
# Створіть категоріальну діаграму, щоб відобразити розподіл покупок за статтею.

# %%
# Категоріальна діаграма для статі (gender): 
# Створіть категоріальну діаграму, щоб відобразити розподіл покупок за статтю. 
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='category', hue ='gender', palette='pastel')
plt.title('Розподіл покупок за статтю')
plt.xlabel('Категорія товарів')
plt.ylabel('Кількість покупок')
plt.show()

# %% [markdown]
# 6.	Залежність між рейтингом і сумою покупок (review_rating і purchase_amount):
# Вивчіть, чи існує зв'язок між рейтингом товару і сумою покупок за допомогою scatter plot.

# %%
# Залежність між рейтингом і сумою покупок (review_rating і purchase_amount): 
# Вивчіть, чи існує зв'язок між рейтингом товару і сумою покупок за допомогою scatter plot. 
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='review_rating', y='purchase_amount_(usd)', color='purple')
plt.title('Залежність між рейтингом і сумою покупок')
plt.xlabel('Рейтинг')
plt.ylabel('Сума покупок')
plt.show()

# %% [markdown]
# 7.	Сезонність покупок (season):
# Побудуйте стовпчату діаграму, яка відображає, в який сезон клієнти роблять найбільше покупок.

# %%
# Сезонність покупок (season)
# Побудуйте стовпчату діаграму, яка відображає, в який сезон клієнти роблять найбільше покупок. 
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='season', color='springgreen')
plt.title('Сезонність покупок')
plt.xlabel('Сезон')
plt.ylabel('Кількість покупок')
plt.show()

# %% [markdown]
# 8.	Графік розподілу розмірів одягу (size):
# Створіть графік розподілу розмірів одягу, щоб визначити популярність різних розмірів.

# %%
# Графік розподілу розмірів одягу (size)
# Створіть графік розподілу розмірів одягу, щоб визначити популярність різних розмірів. 
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='size', order=df['size'].value_counts().index, hue='category', palette='muted')
plt.title('Розподіл розмірів одягу')
plt.xlabel('Розмір')
plt.ylabel('Кількість покупок')
plt.show()

# %% [markdown]
# 9.	Кількість покупок відносно типу оплати (payment_method):
# Порівняйте, скільки покупок робиться за різними методами оплати за допомогою стовпчатої діаграми.

# %%
# Кількість покупок відносно типу оплати (payment_method)
# Порівняйте, скільки покупок робиться за різними методами оплати за допомогою стовпчатої діаграми. 
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='payment_method', color='#29AB87')
plt.title('Кількість покупок за типом оплати')
plt.xlabel('Тип оплати')
plt.ylabel('Кількість покупок')
plt.show()

# %% [markdown]
# 10.	Залежність між кількістю попередніх покупок (previous_purchases) і сумою поточної покупки (purchase_amount):Створіть scatter plot для визначення, чи існує зв'язок між кількістю попередніх покупок та сумою поточної покупки.

# %%
# Залежність між кількістю попередніх покупок (previous_purchases) і сумою поточної покупки (purchase_amount)
# Створіть scatter plot для визначення, чи існує зв'язок між кількістю попередніх покупок та сумою поточної покупки. 
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='previous_purchases', y='purchase_amount_(usd)', color='#FD673A')
plt.title('Залежність між кількістю попередніх покупок та сумою поточної покупки')
plt.xlabel('Кількість попередніх покупок')
plt.ylabel('Сума покупок')
plt.show()

# %% [markdown]
# ## Завдання 2

# %% [markdown]
# Побудуйте графік поверхні (3D surface plot) для візуалізації залежності між трьома числовими змінними з використанням бібліотеки Seaborn.
#
# Налаштуйте відображення графіка, включаючи назву графіку, підписи осей і інші необхідні параметри для кращого розуміння візуалізації.
#
# Додайте кольорову легенду.

# %%
import numpy as np

# Генеруємо дані
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# Побудова графіка поверхні
plt.figure(figsize=(10, 6))
ax = plt.axes(projection='3d')
surf = ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')
ax.set_title('3D Surface Plot')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.colorbar(surf, ax=ax, shrink=0.5, aspect=5)  # Додавання кольорової легенди
plt.show()

# %% [markdown]
# ## Завдання 3

# %% [markdown]
# Побудуйте графік теплової поверхні для візуалізації залежності між двома або більше числовими змінними на основі матриці даних, використовуючи бібліотеку Seaborn.

# %%
# Генеруємо дані у вигляді матриці
data_matrix=np.zeros((10, 10))
for x in range(1, 11): 
    for y in range(1, 11):
        data_matrix[x-1][y-1]=np.sin(x/y)
print(data_matrix)

# Побудова графіка теплової поверхні
plt.figure(figsize=(10, 6))
sns.heatmap(data_matrix, cmap='coolwarm', annot=True, fmt=".2f")  # annot - показує значення на діаграмі, fmt - формат значень
plt.title('Heatmap sin(x/y)')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# [[ 0.84147098  0.47942554  0.3271947   0.24740396  0.19866933  0.16589613
#    0.14237173  0.12467473  0.11088263  0.09983342]
#  [ 0.90929743  0.84147098  0.6183698   0.47942554  0.38941834  0.3271947
#    0.28184285  0.24740396  0.22039774  0.19866933]
#  [ 0.14112001  0.99749499  0.84147098  0.68163876  0.56464247  0.47942554
#    0.41557185  0.36627253  0.3271947   0.29552021]
#  [-0.7568025   0.90929743  0.9719379   0.84147098  0.71735609  0.6183698
#    0.54083421  0.47942554  0.42995636  0.38941834]
#  [-0.95892427  0.59847214  0.99540796  0.94898462  0.84147098  0.74017685
#    0.6550779   0.58509727  0.52741539  0.47942554]
#  [-0.2794155   0.14112001  0.90929743  0.99749499  0.93203909  0.84147098
#    0.75597537  0.68163876  0.6183698   0.56464247]
#  [ 0.6569866  -0.35078323  0.72308588  0.98398595  0.98544973  0.91944498
#    0.84147098  0.7675435   0.70169788  0.64421769]
#  [ 0.98935825 -0.7568025   0.45727263  0.90929743  0.9995736   0.9719379
#    0.90982291  0.84147098  0.77637192  0.71735609]
#  [ 0.41211849 -0.97753012  0.14112001  0.7780732   0.97384763  0.99749499
#    0.95963858  0.90226759  0.84147098  0.78332691]
#  [-0.54402111 -0.95892427 -0.19056796  0.59847214  0.90929743  0.99540796
#    0.98990308  0.94898462  0.8961922   0.84147098]]

# %% [markdown]
# ### Висновок

# %% [markdown]
# Під час виконання лабораторної роботи з аналізу даних Customer Shopping Trends Dataset було проведено ряд аналітичних та візуалізаційних операцій для отримання важливих інсайтів. Основні висновки з роботи:
#
# 1. Було проведено попередню обробку даних, включаючи перевірку розміру таблиці, виявлення пропусків та дублікатів, а також перевірку типів стовпців. Назви стовпців було перейменовано згідно вимог.
# 2. Побудовано гістограму віку клієнтів, що дозволило оцінити розподіл віку серед покупців.
# 3. Створено стовпчасту діаграму для порівняння розподілу покупок за різними категоріями товарів, що дозволило визначити найпопулярніші товари серед клієнтів.
# 4. Використано scatter plot для візуалізації залежності між віком клієнтів та сумою їхніх покупок, що дозволило виявити можливі кореляції між цими змінними.
# 5. Побудовано графік розподілу оцінок товарів, що дозволило оцінити якість придбаних товарів.
# 6. Створено категоріальну діаграму, щоб відобразити розподіл покупок за статтею, що дозволило оцінити, яка стать здійснює більше покупок.
# 7. Використано scatter plot для дослідження зв'язку між рейтингом товару та сумою покупок, що дозволило визначити, чи існує залежність між цими змінними.
# 8. Побудовано стовпчату діаграму, що відображає, в який сезон клієнти роблять найбільше покупок, що дозволило виявити сезонні тенденції.
# 9. Проведено аналіз розподілу розмірів одягу серед покупців, що дозволило визначити популярність різних розмірів.
# 10. Порівняно кількість покупок за різними методами оплати за допомогою стовпчатої діаграми.
# 11. Використано scatter plot для визначення зв'язку між кількістю попередніх покупок та сумою поточної покупки.
#
# Крім того, виконано два додаткових завдання:
#
# 1. Побудовано графік поверхні для візуалізації залежності між трьома числовими змінними.
# 2. Побудовано графік теплової поверхні для візуалізації залежності між двома або більше числовими змінними на основі матриці даних.
#
# Отже, виконавши дану лабораторну роботу, було отримано глибокі інсайти щодо поведінки клієнтів та їхніх покупок, а також вивчено взаємозв'язки між різними параметрами.
